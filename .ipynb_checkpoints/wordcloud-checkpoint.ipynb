# %% [markdown]
# # Final Project

# %%
# Import statements
import os
import re
import nltk
import pandas as pd
import numpy as np
from afinn import Afinn
import matplotlib.pyplot as plt

# %%
def create_df(c):
    df = pd.DataFrame()
    divider = []
    names = []
    for f in os.listdir("tweets/%s" % c):
        try:
            dft = pd.read_csv("tweets/%s/%s" % (c, f))
            if len(divider) == 0:
                divider.append(len(dft) - 1)
            else:
                divider.append(len(dft) + divider[-1])
            df = pd.concat([df, dft])
            # parse output_name.csv string
            names.append(f[7:][:-4])
        except:
            print(f)
    return df, divider, names

# %%
categories = ["fast food", "airlines", "leagues", "colleges", "streaming platforms", "news", "tech giants", "celebrities"]

fast_food, ff_divider, ff_names = create_df(categories[0])
airlines, al_divider, al_names = create_df(categories[1])
leagues, lg_divider, lg_names = create_df(categories[2])
colleges, cl_divider, cl_names = create_df(categories[3])
streaming, st_divider, st_names = create_df(categories[4])
news, nw_divider, nw_names = create_df(categories[5])
tech, tg_divider, tg_names = create_df(categories[6])
celebs, cb_divider, cb_names = create_df(categories[7])
# Out:
#                    date    username               to  replies  retweets  \
# 0   2019-11-28 01:01:08  jimmyjohns              NaN        2         5
# 1   2019-11-27 17:43:19  jimmyjohns              NaN        1         0
# 2   2019-11-27 17:33:00  jimmyjohns         _amb333r        0         0
# 3   2019-11-27 17:11:32  jimmyjohns      THYCROSSMAN        1         1
# 4   2019-11-27 16:59:28  jimmyjohns    thatboyjoelll        1         2
# ..                  ...         ...              ...      ...       ...
# 95  2019-11-26 18:53:00  jimmyjohns   BoostCreditLLC        0         0
# 96  2019-11-26 18:51:52  jimmyjohns  davidjdickerson        0         0
# 97  2019-11-26 18:44:33  jimmyjohns     TheRosenOne1        0         0
# 98  2019-11-26 16:51:24  jimmyjohns          shahcma        1         0
# 99  2019-11-26 16:48:00  jimmyjohns        gisell_gg        0         0
#
#     favorites                                               text  geo  \
# 0          63  these parties are getting wild, be careful out...  NaN
# 1          20  Meet the Freaky Fast® Order button. Life just ...  NaN
# 2           0  I'm really sorry for the hold up today! Give t...  NaN
# 3           1                                  I LOVE YOUR LOVE!  NaN
# 4           2                                                NaN  NaN
# ..        ...                                                ...  ...
# 95          0  Can you please DM me your email address linked...  NaN
# 96          0  Please reach out to my team here: http://bit.l...  NaN
# 97          0  I'm sorry if we messed up! Did you contact the...  NaN
# 98          0  Do you have todays order yet? I'll check with ...  NaN
# 99          1                             Love hitting the spot!  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1199855711280386049
# 1       NaN      NaN  1199745532333350913
# 2       NaN      NaN  1199742934989582342
# 3       NaN      NaN  1199737533728481281
# 4       NaN      NaN  1199734495722852352
# ..      ...      ...                  ...
# 95      NaN      NaN  1199400680550752256
# 96      NaN      NaN  1199400396466339840
# 97      NaN      NaN  1199398554328010753
# 98      NaN      NaN  1199370078321549313
# 99      NaN      NaN  1199369222851350532
#
#                                             permalink
# 0   https://twitter.com/jimmyjohns/status/11998557...
# 1   https://twitter.com/jimmyjohns/status/11997455...
# 2   https://twitter.com/jimmyjohns/status/11997429...
# 3           0         Sounds like you have great taste, Tanner!   NaN
# 4           0  Sounds good to us, friend! We are always cravi...  NaN
# ..        ...                                                ...  ...
# 95          1  You are making us hungry, Noah. We hope you st...  NaN
# 96          0  We’re sorry to hear about your order, Brittney...  NaN
# 97          1          We'll have some waiting for you, Lauren!   NaN
# 98          2  Menu availability for breakfast items can vary...  NaN
# 99          1                   Thanks, Jenna! You're the best!   NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1199930966711644160
# 1       NaN      NaN  1199930621994385408
# 2       NaN      NaN  1199930273372286976
# 3       NaN      NaN  1199930114135543813
# 4       NaN      NaN  1199930006815870976
# ..      ...      ...                  ...
# 95      NaN      NaN  1199870002935083008
# 96      NaN      NaN  1199870002863718400
# 97      NaN      NaN  1199860731153436673
# 98      NaN      NaN  1199860570037587968
# 99      NaN      NaN  1199859736180604928
#
#                                             permalink
# 0   https://twitter.com/McDonalds/status/119993096...
# 1   https://twitter.com/McDonalds/status/119993062...
# 2   https://twitter.com/McDonalds/status/119993027...
# 3   https://twitter.com/McDonalds/status/119993011...
# 4   https://twitter.com/McDonalds/status/119993000...
# ..                                                ...
# 95  https://twitter.com/McDonalds/status/119987000...
# 96  https://twitter.com/McDonalds/status/119987000...
# 97  https://twitter.com/McDonalds/status/119986073...
# 98  https://twitter.com/McDonalds/status/119986057...
# 99  https://twitter.com/McDonalds/status/119985973...
#
# [100 rows x 12 columns]
#                    date username            to  replies  retweets  favorites  \
# 0   2019-11-28 01:41:07     IHOP        kdarmo        0         0          0
# 1   2019-11-28 01:38:32     IHOP     alambakis        0         0          0
# 2   2019-11-28 01:37:20     IHOP        ahusty        0         0          0
# 3   2019-11-27 15:00:53     IHOP           NaN        1         4         33
# 4   2019-11-27 14:53:23     IHOP    beckfergie        0         0          0
# ..                  ...      ...           ...      ...       ...        ...
# 95  2019-11-12 00:17:07     IHOP   Aly10267545        0         0          0
# 96  2019-11-11 16:00:01     IHOP  KrispyKlinic        0         1          4
# 97  2019-11-11 15:57:11     IHOP   LeoCruz1787        0         0          1
# 98  2019-11-11 15:52:31     IHOP     hfrance62        0         0          1
# 99  2019-11-11 15:40:42     IHOP     embogaudo        0         0          1
#
#                                                  text  geo mentions hashtags  \
# 0   Hi Kathy, we’re here to help, please send us a...  NaN      NaN      NaN
# 1   Oh pancakes our bad! Please send us a DM so we...  NaN      NaN      NaN
# 2   Hi Andrea, thank you for bringing this to our ...  NaN      NaN      NaN
# 3   The Elf on the Shelf is in the hot seat talkin...  NaN      NaN      NaN
# 4   Hi Becky! That’s not right, please send us a D...  NaN      NaN      NaN
# ..                                                ...  ...      ...      ...
# 95  Hi Aly, thank you for taking the time to share...  NaN      NaN      NaN
# 96   Thank you for your service, Happy Veterans Day!   NaN      NaN      NaN
# 97  Thank you for your service and for pancaking w...  NaN      NaN      NaN
# 98  Thank you for your service and for pancaking w...  NaN      NaN      NaN
# 99                                            Always.  NaN      NaN      NaN
#
#                      id                                          permalink
# 0   1199865774598500363  https://twitter.com/IHOP/status/11998657745985...
# 1   1199865124288434177  https://twitter.com/IHOP/status/11998651242884...
# 2   1199864821874909184  https://twitter.com/IHOP/status/11998648218749...
# 3   1199704653140832258  https://twitter.com/IHOP/status/11997046531408...
# 4   1199702765968199680  https://twitter.com/IHOP/status/11997027659681...
# ..                  ...                                                ...
# 95  1194046427426672640  https://twitter.com/IHOP/status/11940464274266...
# 96  1193921328409174016  https://twitter.com/IHOP/status/11939213284091...
# 97  1193920617277534208  https://twitter.com/IHOP/status/11939206172775...
# 98  1193919440632594434  https://twitter.com/IHOP/status/11939194406325...
# 99  1193916469832224769  https://twitter.com/IHOP/status/11939164698322...
#
# [100 rows x 12 columns]
#                    date    username               to  replies  retweets  \
# 0   2019-11-28 04:34:30  BurgerKing  CRNP4Resistance        0         0
# 1   2019-11-28 04:34:00  BurgerKing      HollyBear92        0         0
# 2   2019-11-28 04:32:18  BurgerKing    backlog_blues        0         0
# 3   2019-11-28 04:21:25  BurgerKing      So_ShayShay        0         0
# 4   2019-11-28 04:20:53  BurgerKing       MattJakes7        0         0
# ..                  ...         ...              ...      ...       ...
# 95  2019-11-21 03:41:52  BurgerKing    michysketches        0         1
# 96  2019-11-20 23:21:12  BurgerKing      RookRowland        1         1
# 97  2019-11-20 23:20:24  BurgerKing       JPKarwacki        0         0
# 98  2019-11-20 22:48:37  BurgerKing    smellin_ellen        1         0
# 99  2019-11-20 22:27:01  BurgerKing   MinardiCeiling        1         0
#
#     favorites                                               text  geo  \
# 0           0                         Look out for a DM from us.  NaN
# 1           0  we understand the gravity of this situation, H...  NaN
# 2           0  this isn’t the quality we’d expect. plz DM us ...  NaN
# 3           0  hi, Shay, plz send us a DM with more informati...  NaN
# 4           0  thanks for bringing this to our attention, Mat...  NaN
# ..        ...                                                ...  ...
# 95         35                             nothing’s stopping you  NaN
# 96         97   you’d have a promising career naming nail polish  NaN
# 97          0                                           so close  NaN
# 98          4                                       likely story  NaN
# 99          1     we are not accepting negotiations at this time  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1199909406839885824
# 1       NaN      NaN  1199909280041852929
# 2       NaN      NaN  1199908855335063554
# 3       NaN      NaN  1199906115347255296
# 4       NaN      NaN  1199905979363708931
# ..      ...      ...                  ...
# 95      NaN      NaN  1197359447892463617
# 96      NaN      NaN  1197293846968844288
# 97      NaN      NaN  1197293646657269760
# 98      NaN      NaN  1197285649323380736
# 99      NaN      NaN  1197280211383070721
#
#                                             permalink
# 0   https://twitter.com/BurgerKing/status/11999094...
# 1   https://twitter.com/BurgerKing/status/11999092...
# 2   https://twitter.com/BurgerKing/status/11999088...
# 3   https://twitter.com/BurgerKing/status/11999061...
# 4   https://twitter.com/BurgerKing/status/11999059...
# ..                                                ...
# 95  https://twitter.com/BurgerKing/status/11973594...
# 96  https://twitter.com/BurgerKing/status/11972938...
# 97  https://twitter.com/BurgerKing/status/11972936...
# 98  https://twitter.com/BurgerKing/status/11972856...
# 99  https://twitter.com/BurgerKing/status/11972802...
#
# [100 rows x 12 columns]
#
# [100 rows x 12 columns]
#                    date        username              to  replies  retweets  \
# 0   2019-11-28 21:51:33  SpiritAirlines    vamsiKrishin        0         0
# 1   2019-11-28 19:56:40  SpiritAirlines      ClaySaysit        0         0
# 2   2019-11-28 17:36:38  SpiritAirlines      jannifer_n        0         0
# 3   2019-11-28 17:29:42  SpiritAirlines  vishalkverma05        0         0
# 4   2019-11-28 17:16:24  SpiritAirlines    Turtle_Mocha        0         0
# ..                  ...             ...             ...      ...       ...
# 95  2019-11-26 19:00:56  SpiritAirlines    lizettematos        2         0
# 96  2019-11-26 19:00:16  SpiritAirlines             NaN        1         3
# 97  2019-11-26 18:46:52  SpiritAirlines        Minkaro0        0         0
# 98  2019-11-26 18:46:37  SpiritAirlines   AWainwrightTV        0         0
# 99  2019-11-26 18:36:00  SpiritAirlines     GDjajaputra        0         0
#
#     favorites                                               text  geo  \
# 0           0  We’re sorry to hear you’ve had such a frustrat...  NaN
# 1           0  We really want to assist you, please send us a...  NaN
# 2           0  We’re disappointed in the service you’ve descr...  NaN
# 3           0  Vishal - So that we can continue to assist. Pl...  NaN
# 4           0  Hello! We don't like that you've had a negativ...  NaN
# ..        ...                                                ...  ...
# 95          0  Thank you for reaching out to us about this. P...  NaN
# 96          7  Hartsfield-Jackson International Airport in At...  NaN
# 97          1  Hello, we don't like that you've had a negativ...  NaN
# 98          0  We really want to assist you, Alexis, please s...  NaN
# 99          1  We certainly want to look into this. Please DM...  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1200170387918770182
# 1       NaN      NaN  1200141479831855111
# 2       NaN      NaN  1200106236223594501
# 3       NaN      NaN  1200104493586796544
# 4       NaN      NaN  1200101146792202240
# ..      ...      ...                  ...
# 95      NaN      NaN  1199402674774560770
# 96      NaN      NaN  1199402508847849472
# 97      NaN      NaN  1199399137722208258
# 98      NaN      NaN  1199399072043601922
# 99      NaN      NaN  1199396400909430785
#
#                                             permalink
# 0   https://twitter.com/SpiritAirlines/status/1200...
# 1   https://twitter.com/SpiritAirlines/status/1200...
# 2   https://twitter.com/SpiritAirlines/status/1200...
# 3   https://twitter.com/SpiritAirlines/status/1200...
# 4   https://twitter.com/SpiritAirlines/status/1200...
# ..                                                ...
# 95  https://twitter.com/SpiritAirlines/status/1199...
# 96  https://twitter.com/SpiritAirlines/status/1199...
# 97  https://twitter.com/SpiritAirlines/status/1199...
# 98  https://twitter.com/SpiritAirlines/status/1199...
# 99  https://twitter.com/SpiritAirlines/status/1199...
#
# [100 rows x 12 columns]
#                    date username               to  replies  retweets  \
# 0   2019-11-28 14:12:51  JetBlue         SeanJava        0         1
# 1   2019-11-28 14:10:24  JetBlue        Jim_Breez        1         0
# 2   2019-11-28 14:04:19  JetBlue        Jim_Breez        2         0
# 3   2019-11-28 14:02:07  JetBlue   NotQuiteDrBarr        0         0
# 4   2019-11-28 14:00:03  JetBlue              NaN        4         1
# ..                  ...      ...              ...      ...       ...
# 95  2019-11-27 20:34:53  JetBlue        MobergVes        0         0
# 96  2019-11-27 20:23:55  JetBlue  __alyssamichele        0         0
NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1200180855265619971
# 1       NaN      NaN  1200180538427838465
# 2       NaN      NaN  1200179525922934784
# 3       NaN      NaN  1200179366325391360
# 4       NaN      NaN  1200179082543026177
# ..      ...      ...                  ...
# 95      NaN      NaN  1200109138690236416
# 96      NaN      NaN  1200106969907916800
# 97      NaN      NaN  1200106254225399808
# 98      NaN      NaN  1200105778322870272
# 99      NaN      NaN  1200105617064525824
#
#                                             permalink
# 0   https://twitter.com/SouthwestAir/status/120018...
# 1   https://twitter.com/SouthwestAir/status/120018...
# 2   https://twitter.com/SouthwestAir/status/120017...
# 3   https://twitter.com/SouthwestAir/status/120017...
# 4   https://twitter.com/SouthwestAir/status/120017...
# ..                                                ...
# 95  https://twitter.com/SouthwestAir/status/120010...
# 96  https://twitter.com/SouthwestAir/status/120010...
# 97  https://twitter.com/SouthwestAir/status/120010...
# 98  https://twitter.com/SouthwestAir/status/120010...
# 99  https://twitter.com/SouthwestAir/status/120010...
#
# [100 rows x 12 columns]
#                    date      username               to  replies  retweets  \
# 0   2019-11-28 13:49:42  SingaporeAir       samjoss007        1         0
# 1   2019-11-28 12:37:37  SingaporeAir     Character_32        0         0
# 2   2019-11-28 12:35:49  SingaporeAir       samjoss007        1         0
# 3   2019-11-28 11:24:54  SingaporeAir           nmvpcp        0         0
# 4   2019-11-28 11:08:31  SingaporeAir           nmvpcp        1         0
# ..                  ...           ...              ...      ...       ...
# 95  2019-11-24 03:15:13  SingaporeAir       fireopal82        1         0
# 96  2019-11-24 02:45:24  SingaporeAir        monishakr        1         0
# 97  2019-11-24 02:40:15  SingaporeAir         ladyxtel        1         0
# 98  2019-11-24 02:01:45  SingaporeAir         ladyxtel        1         0
# 99  2019-11-24 01:40:22  SingaporeAir  LaurenAnggraini        0         0
#
#     favorites                                               text  geo  \
# 0           0  Hi there, we have received and responded to yo...  NaN
# 1           0  Hi there, we are sorry to hear this. May we ch...  NaN
# 2           0  Thank you for clarifying. May we seek your con...  NaN
# 3           0  Thank you for the clarification. You may wish ...  NaN
# 4           0  Hi there, may we check if this is regarding a ...  NaN
# ..        ...                                                ...  ...
# 95          0  Hi there, thank you for sharing your feedback....  NaN
# 96          0  Hi there, we are sorry to hear this. May we ch...  NaN
# 97          1  Hi Christel, thank you for the details. We hav...  NaN
# 98          0  Hi there, thank you for reaching out to us. Ma...  NaN
# 99          0  Hi there, may we check if you are receiving an...  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1200049127259721728
# 1       NaN      NaN  1200030988837048321
# 2       NaN      NaN  1200030533318828033
# 3       NaN      NaN  1200012686047809538
# 4       NaN      NaN  1200008563374088192
# ..      ...      ...                  ...
# 95      NaN      NaN  1198439902398091264
# 96      NaN      NaN  1198432399727693826
# 97      NaN      NaN  1198431103318671361
# 98      NaN      NaN  1198421412828123142
# 99      NaN      NaN  1198416034040029186
#
#                                             permalink
# 0   https://twitter.com/SingaporeAir/status/120004...
# 1   https://twitter.com/SingaporeAir/status/120003...
# 2   https://twitter.com/SingaporeAir/status/120003...
# 3   https://twitter.com/SingaporeAir/status/120001...
# 4   https://twitter.com/SingaporeAir/status/120000...
# ..                                                ...
# 95  https://twitter.com/SingaporeAir/status/119843...
# 96  https://twitter.com/SingaporeAir/status/119843...
# 97  https://twitter.com/SingaporeAir/status/119843...
# 98  https://twitter.com/SingaporeAir/status/119842...
# 99  https://twitter.com/SingaporeAir/status/119841...
#
# [100 rows x 12 columns]
#                    date     username               to  replies  retweets  \
# 0   2019-11-28 14:09:31  AmericanAir       Mrebes1360        0         0
# 1   2019-11-28 14:08:26  AmericanAir      310BPreston        0         0
# 2   2019-11-28 14:08:12  AmericanAir   MattyStratty22        0         0
# 3   2019-11-28 13:56:44  AmericanAir     Indobritdawg        0         0
# 4   2019-11-28 13:54:00  AmericanAir  middleeastfeas1        0         0
# ..                  ...          ...              ...      ...       ...
# 95  2019-11-28 05:29:39  AmericanAir    insuranceguye        0         0
# 96  2019-11-28 05:27:15  AmericanAir     parkwahlberg        0         0
# 97  2019-11-28 05:25:54  AmericanAir         linzgibz        1         0
# 98  2019-11-28 05:21:43  AmericanAir     parkwahlberg        1         0
# 99  2019-11-28 05:17:50  AmericanAir        dc4kamala        0         0
#
#     favorites                                               text  geo  \
# 0           0  It's never our intention to cause any disrupti...  NaN
# 1           0                     Hey there! Happy Thanksgiving.  NaN
# 2           0  If you're asked to gate check due to space the...  NaN
# 3           0  Hooray for Chris and he sounds like a real gem...  NaN
# 4           0  Our crews work to monitor bin space and we can...  NaN
# ..        ...                                                ...  ...
# 95          0  We have the best pilots in the biz and safety ...  NaN
# 96          0                            Great, we're here 24/7.  NaN
# 97          1  A clean ride is a must. We'd like to forward t...  NaN
# 98          0         What's going on, Park? We're here to help.  NaN
# 99          1  We're so glad that this soldier can be with fa...  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1200054113276444672
# 1       NaN      NaN  1200053840697004032
# 2       NaN      NaN  1200053782412955650
# 3       NaN  #AATeam  1200050896354381825
# 4       NaN      NaN  1200050208962416644
# ..      ...      ...                  ...
# 95      NaN      NaN  1199923284726484992
# 96      NaN      NaN  1199922681354838016
# 97      NaN      NaN  1199922341758873600
# 98      NaN      NaN  1199921291073069056
# 99      NaN      NaN  1199920310956548098
#
#                                             permalink
# ...
# ..                  ...      ...           ...      ...       ...        ...
# 95  2019-10-27 17:37:57  TheRock   JerryLawler       22        96       1313
# 96  2019-10-26 23:25:58  TheRock           NaN      395       612      13759
# 97  2019-10-22 15:52:36  TheRock           NaN      208       430       6822
# 98  2019-10-21 06:13:53  TheRock   LFAfighting       79       300       3520
# 99  2019-10-20 18:43:54  TheRock           NaN       70       653      11106
#
#                                                  text  geo  \
# 0    yeah that Rock fella has a big mouth. I never...  NaN
# 1   Stay strong, Zola-Rain. You inspire all of us ...  NaN
# 2   Like twinning and looking in the mirror, Ash. ...  NaN
# 3   From our dysfunctional, yet loving family to y...  NaN
# 4            where’s my gobble gobble @KevinHart4real  NaN
# ..                                                ...  ...
# 95  You can use the Rock Bottom anytime, King. Con...  NaN
# 96  Happy 71st Birthday to best mom this lucky dud...  NaN
# 97  As a father to 3 beautiful girls and a big dad...  NaN
# 98                                  #motivationmonday  NaN
# 99  HAPPY BDAY to my brother @johnkrasinski &amp; ...  NaN
#
#                        mentions           hashtags                   id  \
# 0                           NaN                NaN  1200201422630834176
# 1                           NaN                NaN  1200096687894614016
# 2                           NaN                NaN  1199870478875152391
# 3               @KevinHart4real                NaN  1199868653459529730
# 4               @KevinHart4real                NaN  1199771123245670400
# ..                          ...                ...                  ...
# 95                          NaN                NaN  1188510155794599936
# 96                          NaN                NaN  1188235349618765828
# 97              @KevinHart4real            #tijasi  1186671704979828739
# 98                          NaN  #motivationmonday  1186163676895514625
# 99  @johnkrasinski @familyreach                NaN  1185990037734711296
#
#                                             permalink
# 0   https://twitter.com/TheRock/status/12002014226...
# 1   https://twitter.com/TheRock/status/12000966878...
# 2   https://twitter.com/TheRock/status/11998704788...
# 3   https://twitter.com/TheRock/status/11998686534...
# 4   https://twitter.com/TheRock/status/11997711232...
# ..                                                ...
# 95  https://twitter.com/TheRock/status/11885101557...
# 96  https://twitter.com/TheRock/status/11882353496...
# 97  https://twitter.com/TheRock/status/11866717049...
# 98  https://twitter.com/TheRock/status/11861636768...
# 99  https://twitter.com/TheRock/status/11859900377...
#
# [100 rows x 12 columns]
#                    date         username               to  replies  retweets  \
# 0   2019-11-28 16:25:43  VancityReynolds  TheRealJenCandy        3         2
# 1   2019-11-28 15:29:23  VancityReynolds              NaN      643      7698
# 2   2019-11-27 23:50:16  VancityReynolds              Inc      105       135
# 3   2019-11-26 18:01:48  VancityReynolds   theYoungCenter       40       349
# 4   2019-11-25 15:12:01  VancityReynolds       journeydan       13        16
# ..                  ...              ...              ...      ...       ...
# 95  2019-09-15 02:47:16  VancityReynolds              NaN      627      4081
# 96  2019-09-12 14:37:33  VancityReynolds   jediminndtrick        8        15
# 97  2019-09-12 14:12:30  VancityReynolds   jediminndtrick     1848     47382
# 98  2019-09-11 01:18:56  VancityReynolds  AmosTraskPirate       11        13
# 99  2019-09-09 20:33:21  VancityReynolds        Gbarnes40       13        34
#
#     favorites                                               text  geo  \
# 0         112                                                     NaN
# 1       83823  Happy Thanksgiving, America. Happy Thursday, C...  NaN
# 2        3698  This is the reason. The number one reason I bo...  NaN
# 3        3244  Match Madness? Yes please! #MatchUs @theYoungC...  NaN
# 4         536                                        True story.  NaN
# ..        ...                                                ...  ...
# 95      53901     .@fleabag is so good I wish I’d never seen it.  NaN
# 96        597                                                     NaN
# 97     382004  No. Put on Spider-Man (from 2002) and tell him...  NaN
# 98        519  No. But @AviationGin causes high fives and in ...  NaN
# 99        807  Hey Gregg, the money for @NAACP_LDF helps comb...  NaN
#
#                       mentions  hashtags                   id  \
# 0                          NaN       NaN  1200088388788985869
# 1                          NaN       NaN  1200074215745052672
# 2                 @_MintMobile       NaN  1199837879087878145
# 3              @theYoungCenter  #MatchUs  1199387792910016512
# 4                          NaN       NaN  1198982681310244864
# ..                         ...       ...                  ...
# 95                    @fleabag       NaN  1173065717178085376
# 96                         NaN       NaN  1172157302578847745
# 97                         NaN       NaN  1172151000930631680
# 98                @AviationGin       NaN  1171593939062861825
# 99  @NAACP_LDF @theYoungCenter       NaN  1171159678635712513
#
#                                             permalink
# 0   https://twitter.com/VancityReynolds/status/120...
# 1   https://twitter.com/VancityReynolds/status/120...
# 2   https://twitter.com/VancityReynolds/status/119...
# 3   https://twitter.com/VancityReynolds/status/119...
# 4   https://twitter.com/VancityReynolds/status/119...
# ..                                                ...
# 95  https://twitter.com/VancityReynolds/status/117...
# 96  https://twitter.com/VancityReynolds/status/117...
# 97  https://twitter.com/VancityReynolds/status/117...
# 98  https://twitter.com/VancityReynolds/status/117...
# 99  https://twitter.com/VancityReynolds/status/117...
#
# [100 rows x 12 columns]
#                    date        username   to  replies  retweets  favorites  \
# 0   2019-11-28 17:02:52  KevinHart4real  NaN       49        35        602
# 1   2019-11-28 15:24:09  KevinHart4real  NaN      163       540       4718
# 2   2019-11-26 23:18:11  KevinHart4real  NaN        5         3         23
# 3   2019-11-26 22:46:47  KevinHart4real  NaN        0         8         60
# 4   2019-11-26 22:45:03  KevinHart4real  NaN        1         6         54
# ..                  ...             ...  ...      ...       ...        ...
# 95  2019-07-28 14:14:47  KevinHart4real  NaN       29        40        622
# 96  2019-07-27 13:37:18  KevinHart4real  NaN       71        69       1728
# 97  2019-07-26 23:14:03  KevinHart4real  NaN       44        51        847
# 98  2019-07-25 22:07:32  KevinHart4real  NaN       44        55        961
# 99  2019-07-25 21:53:13  KevinHart4real  NaN       23        28        598
#
#                                                  text  geo  \
# 0   Happy Thanksgiving People!!!!! #LiveLoveLaugh ...  NaN
# 1   So much to be thankful for....Happy thanksgivi...  NaN
# 2   @ErinAndrews trying to get me to cancel my own...  NaN
# 3   @ErinAndrews trying to get me to cancel my own...  NaN
# 4   @ErinAndrews trying to get me to cancel my own...  NaN
# ..                                                ...  ...
# 95  #Harts https://www.instagram.com/p/B0dqHO2F4ba...  NaN
# 96  Received the "Generation Award" at the Just Fo...  NaN
# 97  Grown Little 40yr old man.... #ComedicRockStar...  NaN
# 98  Make sure y'all tune into a all new episode of...  NaN
# 99  On set with my team #Harts #Fatherhood https:/...  NaN
#
#                               mentions  \
# 0                                  NaN
# 1                                  NaN
# 2                         @ErinAndrews
# 3             @ErinAndrews @LOLNetwork
# 4   @ErinAndrews @LOLNetwork @NFLonFOX
# ..                                 ...
# 95                                 NaN
# 96                                 NaN
# 97                                 NaN
# 98                                 NaN
# 99                                 NaN
#
#                                              hashtags                   id  \
# 0                                      #LiveLoveLaugh  1200097739264155648
# 1                                                 NaN  1200072896388841473
# 2   #ColdasBalls #PoweredbyOldSpice #CABSeason3 #F...  1199467416130113536
# 95  https://twitter.com/lizzo/status/1191301921228...
# 96  https://twitter.com/lizzo/status/1191295500642...
# 97  https://twitter.com/lizzo/status/1191077446721...
# 98  https://twitter.com/lizzo/status/1191050893153...
# 99  https://twitter.com/lizzo/status/1190486375042...
#
# [100 rows x 12 columns]
#                    date username               to  replies  retweets  \
# 0   2019-11-27 22:22:07     Uber     MadMaxCorral        0         0
# 1   2019-11-27 22:21:46     Uber       SINFULNINI        1         0
# 2   2019-11-27 22:21:05     Uber        WumiTuase        0         0
# 3   2019-11-27 22:20:30     Uber     amarteymusic        0         0
# 4   2019-11-27 21:40:24     Uber  asaguarofromMTY        6         7
# ..                  ...      ...              ...      ...       ...
# 95  2019-11-05 21:10:31     Uber      jamilawoods        0         0
# 96  2019-11-05 21:09:21     Uber      Castleheart        0         0
# 97  2019-11-05 20:54:30     Uber       Soniyeahhh        0         0
# 98  2019-11-05 20:53:50     Uber        zalahabib        0         0
# 99  2019-11-05 20:53:00     Uber          yamiixv        1         0
#
#     favorites                                               text  geo  \
# 0           1                   Good starts lead to great days.   NaN
# 1           1                  Top of the afternoon to you too.   NaN
# 2           0                                                     NaN
# 3           1                                    Concert for 1.   NaN
# 4          66                   Not all superheroes wear capes.   NaN
# ..        ...                                                ...  ...
# 95          0  Hi Jamila! We love your tweet and would like t...  NaN
# 96          0  Hi! We love your tweet and would like to share...  NaN
# 97          0  Hi Sonia! We love your tweet and would like to...  NaN
# 98          0  Hi! We love your tweet and would like to share...  NaN
# 99          1  Hi! We love your tweet and would like to share...  NaN
#
#    mentions hashtags                   id  \
# 0       NaN      NaN  1199815692574281728
# 1       NaN      NaN  1199815606427475968
# 2       NaN      NaN  1199815432514879489
# 3       NaN      NaN  1199815285227700224
# 4       NaN      NaN  1199805196257247232
# ..      ...      ...                  ...
# 95      NaN      NaN  1191825141526863872
# 96      NaN      NaN  1191824847812354048
# 97      NaN      NaN  1191821112176447488
# 98      NaN      NaN  1191820943812943879
# 99      NaN      NaN  1191820734290640902
#
#                                             permalink
# 0   https://twitter.com/Uber/status/11998156925742...
# 1   https://twitter.com/Uber/status/11998156064274...
# 2   https://twitter.com/Uber/status/11998154325148...
# 3   https://twitter.com/Uber/status/11998152852277...
# 4   https://twitter.com/Uber/status/11998051962572...
# ..                                                ...
# 95  https://twitter.com/Uber/status/11918251415268...
# 96  https://twitter.com/Uber/status/11918248478123...
# 97  https://twitter.com/Uber/status/11918211121764...
# 98  https://twitter.com/Uber/status/11918209438129...
# 99  https://twitter.com/Uber/status/11918207342906...
#
# [100 rows x 12 columns]

# %%
stopwords = nltk.corpus.stopwords.words("english")

# Clean tweets for sentiment analysis
def get_clean_words(words):
    def _isnum(w):
        try:
            int(w)
            return True
        except ValueError:
            return False
        
    # Set words to lowercase and remove them if they are stop words
    words = [w.lower() for w in words if w.lower() not in stopwords]

    # Remove punctuation
    words = [w.replace('(', '') for w in words]
    words = [w.replace(')', '') for w in words]
    words = [w.replace('?', '') for w in words]
    words = [w.replace(',', '') for w in words]
    words = [w.replace('.', '') for w in words]
    words = [w.replace('"', '') for w in words]
    words = [w.replace('!', '') for w in words]
    words = [w.replace(':', '') for w in words]

    # Remove numbers
    words = [w for w in words if not _isnum(w)]
    
    # Remove links
    words = [w for w in words if 'http' not in w]
        
    # Remove hashtags
    words = [w for w in words if not w.startswith("#")]
    
    # Remove mentions
    words = [w for w in words if not w.startswith("@")]
    
    # Only keep words with more than one character
    words = [w for w in words if len(w) > 1]

    return words

# %%
def clean_tweets(tweets):
    categories = len(tweets)
    print(categories)
    all_tweets = []
    for c in range(categories):
        t_new = []
        count = 0
        for t in tweets[c]:
            try:
                w = t.split()
                w = get_clean_words(w)
                tc = " ".join(w)
                t_new.append(tc)
            except:
                count += 1
        print(count, len(t_new))
        all_tweets.append(t_new)
    return all_tweets

# %%
def split_tweets(category_text, divider):
    category_tweets = []
    for d in divider:
        category_acct = []
        for i, tweet in enumerate(list(category_text)):
            if i <= d:
                category_acct.append(tweet)
            else:
                break
        category_tweets.append(category_acct)
    return category_tweets
    
            
ff_tweets = split_tweets(fast_food['text'], ff_divider)    
al_tweets = split_tweets(airlines['text'], al_divider)  
lg_tweets = split_tweets(leagues['text'], lg_divider)
cl_tweets = split_tweets(colleges['text'], cl_divider)
st_tweets = split_tweets(streaming['text'], st_divider)
nw_tweets = split_tweets(news['text'], nw_divider)
tg_tweets = split_tweets(tech['text'], tg_divider)
cb_tweets = split_tweets(celebs['text'], cb_divider)

ff_clean = clean_tweets(ff_tweets)
al_clean = clean_tweets(al_tweets)
lg_clean = clean_tweets(lg_tweets)
cl_clean = clean_tweets(cl_tweets)
st_clean = clean_tweets(st_tweets)
nw_clean = clean_tweets(nw_tweets)
tg_clean = clean_tweets(tg_tweets)
cb_clean = clean_tweets(cb_tweets)
# Out:
# 10
# 2327 7673
# 2593 17407
# 2594 27406
# 2601 37399
# 2602 47398
# 2683 57317
# 2762 67238
# 2762 77238
# 3015 86985
# 3110 96890
# 10
# 4 9996
# 7 19993
# 502 29498
# 502 39498
# 502 49498
# 503 59497
# 505 69495
# 505 79495
# 505 89495
# 505 91795
# 10
# 136 9864
# 171 19829
# 173 29827
# 331 39669
# 472 49528
# 473 54375
# 474 64374
# 476 74372
# 476 84372
# 476 90970
# 10
# 15 9985
# 16 19984
# 89 29911
# 94 39155
# 108 41885
# 238 51223
# 238 59272
# 238 66553
# 248 73228
# 264 83212
# 10
# 81 9919
# 239 19761
# 659 29341
# 662 34812
# 1206 44268
# 1226 52745
# 2134 61837
# 2186 71371
# 2186 81371
# 2226 84857
# 10
# 0 10000
# 0 20000
# 0 30000
# 0 40000
# 0 50000
# 76 59924
# 113 69887
# 113 79887
# 114 89886
# 140 99860
# 10
# 6 8060
# 6 12567
# 25 14906
# 30 15045
# 30 18676
# 30 21676
# 35 30352
# 66 32021
# 68 42019
# 166 51921
# 10
# 63 8854
# 247 18001
# 475 27773
# 483 30619
# 495 35452
# 497 45450
# 510 46630
# 516 56624
# 579 65478
# 581 69945

# %%
afinn = Afinn()

def get_affinity_scores(tweets):
    scores = []
    for t in tweets:
        if (len(t) > 0):
            scores.append(afinn.score(t) / len(t))
    return scores

# %%
ff_affin = get_affinity_scores(ff_clean)
al_affin = get_affinity_scores(al_clean)
lg_affin = get_affinity_scores(lg_clean)
cl_affin = get_affinity_scores(cl_clean)
st_affin = get_affinity_scores(st_clean)
nw_affin = get_affinity_scores(nw_clean)
tg_affin = get_affinity_scores(tg_clean)
cb_affin = get_affinity_scores(cb_clean)

# %%
plt.hist(ff_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Fast Food Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(al_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Airline Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(lg_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Sports League Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(cl_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("College Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(st_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Streaming Site Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(nw_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("News Outlet Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(tg_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Tech Giant Twitter Sentiment Analysis")
plt.show()

# %%
plt.hist(cb_affin, bins = 20)
plt.xlim([-1, 1])
plt.title("Celebrity Twitter Sentiment Analysis")
plt.show()

# %%
def affin_by_acct(tweets, divider):
    acct = []
    start = 0
    for x in range(len(divider)):
        acct.append(np.mean(get_affinity_scores(tweets[start:divider[x]])))
        start = divider[x] + 1
    return acct

# %%
ff_acct = affin_by_acct(ff_clean, ff_divider)
al_acct = affin_by_acct(al_clean, al_divider)
lg_acct = affin_by_acct(lg_clean, lg_divider)
cl_acct = affin_by_acct(cl_clean, cl_divider)
st_acct = affin_by_acct(st_clean, st_divider)
nw_acct = affin_by_acct(nw_clean, nw_divider)
tg_acct = affin_by_acct(tg_clean, tg_divider)
cb_acct = affin_by_acct(cb_clean, cb_divider)

# %%
plt.bar(ff_names, ff_acct)
plt.title("Fast Food Twitter Sentiment Analysis")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(al_names, al_acct)
plt.title("Airline Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(lg_names, lg_acct)
plt.title("Sports League Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(cl_names, cl_acct)
plt.title("College Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(st_names, st_acct)
plt.title("Streaming Site Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(nw_names, nw_acct)
plt.title("News Outlet Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(tg_names, tg_acct)
plt.title("Tech Giant Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
plt.bar(cb_names, cb_acct)
plt.title("Celebrity Twitter Sentiment Analysis by Account")
plt.xticks(rotation=45)
plt.show()

# %%
# print(ff_clean[0][0:100], ff_clean[1][0:100])
import numpy as np
# ff_clean_new = [f.split() for ff in ff_clean for f in ff]
# ff_clean_new = [w for t in ff_clean_new for w in t]
# print(ff_clean_new[0:100])
#print(tg_clean[0][0:100])
print(np.shape(ff_clean_new))
# Out:
# (4130361,)

# %%
import wordcloud
import matplotlib.pylab as plt
from PIL import Image

char_mask = np.array(Image.open("fastfood2.png"))    
image_colors = wordcloud.ImageColorGenerator(char_mask)

plt.figure(figsize=(12, 18))
text = ' '.join([' '.join(ff_clean[i]) for i in range(len(ff_clean))])
print(text[:200])
wc = wordcloud.WordCloud(background_color="white", max_words=400, max_font_size=40, width=400, height=400, mask=char_mask, collocations=False, random_state=1)
wc.generate(text)
# to recolour the image
plt.imshow(wc.recolor(color_func=image_colors), interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# parties getting wild careful tonight meet freaky fast® order button life got whole lot easier i'm really sorry hold today give store call see what's up love love i'm sorry let store know right away ma
